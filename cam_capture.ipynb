# %%
# import python opencv library to capture images from camera
import cv2

# %%
# create a video capture object
vc_object = cv2.VideoCapture(0)

# grab an image
check, image = vc_object.read()

if check:
    print("success")
else:
    print("fail")

vc_object.release()
# Out:
# success

# %%
# import numpy, matplotlib to process, show image data
import numpy as np
import matplotlib.pyplot as plt

# %%
# show image data
plt.imshow(image[:,:,1], cmap="Greys")
