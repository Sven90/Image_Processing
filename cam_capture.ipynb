# %%
# import python opencv library to capture images from camera
import cv2

# %%
# create a video capture object
vc_object = cv2.VideoCapture(0)

# grab an image
check, image = vc_object.read()

if check:
    print("success")
else:
    print("fail")

vc_object.release()
# Out:
# success

# %%
# import numpy, matplotlib to process, show image data
import numpy as np
import matplotlib.pyplot as plt

# %%
# invert image
image_inv = image[:,:,1].max() - image[:,:,1]

# %%
# show inverted image
plt.imshow(image_inv, cmap="Greys")

# %%
# laplace sharpening
laplacian = cv2.Laplacian(image_inv, cv2.CV_64F)
sharpened_lap = np.uint8(np.clip(image_inv - 0.5*laplacian, 0, 255))
plt.imshow(sharpened_lap, cmap="Greys")
